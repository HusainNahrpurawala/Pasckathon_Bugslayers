# %% [markdown]
# <a href="https://colab.research.google.com/github/anuraagshankar/Pasckathon_Bugslayers/blob/master/same_fill.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler, LabelEncoder, OneHotEncoder, Normalizer, StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, roc_auc_score, confusion_matrix, classification_report, f1_score, recall_score, precision_score, precision_recall_curve, mean_squared_error
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.utils import class_weight
from sklearn.feature_selection import VarianceThreshold
import lightgbm as lgb
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import KFold
import gc
import pdb
from xgboost import XGBRegressor
import os
from tqdm.notebook import tqdm
import pickle
import pdb
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
# !cp '/content/drive/My Drive/sepsis/same_fill/back_fill/dataset.csv'
# !cp '/content/drive/My Drive/sepsis/same_fill/front_fill/dataset.csv' '/content/drive/My Drive/sepsis/same_fill/front_dataset.csv'

# %%
# !unzip /content/drive/My\ Drive/sepsis/training_setA.zip 
# !unzip /content/drive/My\ Drive/sepsis/training_setB.zip

# %%
DIR1 = '/content/training/'
DIR2 = '/content/training_setB/'
FDIR = '/content/drive/My Drive/sepsis/same_fill/front_fill/'
BDIR = '/content/drive/My Drive/sepsis/same_fill/back_fill/'

# %%
files1 = os.listdir(DIR1)
files2 = os.listdir(DIR2)
cols = list(pd.read_csv(DIR1+files1[0],sep='|').columns)

# %%
df1 = pd.read_csv(DIR1+files1[0], sep='|')
df1
# Out:
#        HR  O2Sat   Temp    SBP  ...  Unit2  HospAdmTime  ICULOS  SepsisLabel
# 0     NaN    NaN    NaN    NaN  ...    NaN        -0.03       1            0
# 1    75.0   96.0    NaN  111.0  ...    NaN        -0.03       2            0
# 2    66.0   94.0    NaN  103.0  ...    NaN        -0.03       3            0
# 3    72.0   91.0    NaN  108.0  ...    NaN        -0.03       4            0
# 4    77.0   98.0  36.89  113.0  ...    NaN        -0.03       5            0
# 5    74.0   85.0  36.89  105.0  ...    NaN        -0.03       6            0
# 6    68.0   98.0  36.78  101.0  ...    NaN        -0.03       7            0
# 7    65.0   96.0    NaN  118.0  ...    NaN        -0.03       8            0
# 8    64.0   95.0    NaN  129.0  ...    NaN        -0.03       9            0
# 9    63.0   95.0    NaN  123.0  ...    NaN        -0.03      10            0
# 10   75.0   95.0  36.89  127.0  ...    NaN        -0.03      11            0
# 11   65.0   94.0    NaN  105.0  ...    NaN        -0.03      12            0
# 12   72.0   95.0  36.22  118.0  ...    NaN        -0.03      13            0
# 13   75.0   95.0  36.22  109.0  ...    NaN        -0.03      14            0
# 14   53.0   91.0  36.11  115.0  ...    NaN        -0.03      15            0
# 15    NaN    NaN    NaN    NaN  ...    NaN        -0.03      16            0
# 16   79.0   89.0  36.67  114.0  ...    NaN        -0.03      17            0
# 17   79.0   88.5  36.67  115.5  ...    NaN        -0.03      18            0
# 18   79.5   92.5    NaN  123.5  ...    NaN        -0.03      19            0
# 19   76.0   94.5    NaN  124.0  ...    NaN        -0.03      20            0
# 20   75.0   93.0    NaN  115.0  ...    NaN        -0.03      21            0
# 21   69.0   96.0  36.56  110.0  ...    NaN        -0.03      22            0
# 22   72.0   84.0    NaN  106.0  ...    NaN        -0.03      23            0
# 23   75.0   95.0    NaN  122.0  ...    NaN        -0.03      24            0
# 24   75.0   98.0    NaN  137.0  ...    NaN        -0.03      25            0
# 25   84.0   97.0  36.67  109.0  ...    NaN        -0.03      26            0
# 26   77.0   93.0    NaN  114.0  ...    NaN        -0.03      27            0
# 27   85.0   98.0    NaN    NaN  ...    NaN        -0.03      28            0
# 28   81.0   86.0    NaN  137.0  ...    NaN        -0.03      29            0
# 29  135.0   96.0    NaN  133.0  ...    NaN        -0.03      30            0
# 30  134.0   92.0    NaN  117.0  ...    NaN        -0.03      31            0
# 31   97.0   96.5    NaN  103.0  ...    NaN        -0.03      32            0
# 32  104.0   96.0    NaN  104.0  ...    NaN        -0.03      33            0
# 33   69.0   95.0    NaN  100.0  ...    NaN        -0.03      34            0
# 34   74.0   93.0  36.22  109.0  ...    NaN        -0.03      35            0
# 35   82.0   97.0    NaN  114.0  ...    NaN        -0.03      36            0
# 36   77.0   98.0    NaN  119.0  ...    NaN        -0.03      37            0
# 37   78.0   95.0  34.39  125.0  ...    NaN        -0.03      38            0
# 38  138.0   96.0    NaN  123.0  ...    NaN        -0.03      39            0
# 39  138.0   98.0    NaN  105.0  ...    NaN        -0.03      40            0
# 40  139.0    NaN    NaN  125.0  ...    NaN        -0.03      41            0
# 41  131.0   85.0  36.44  130.0  ...    NaN        -0.03      42            0
# 42  132.0    NaN    NaN  103.0  ...    NaN        -0.03      43            0
# 43  138.0  100.0    NaN   97.0  ...    NaN        -0.03      44            0
# 44  139.0  100.0    NaN  100.0  ...    NaN        -0.03      45            0
# 45  134.0   89.0  36.67   93.0  ...    NaN        -0.03      46            0
# 46  139.0   96.0    NaN  102.0  ...    NaN        -0.03      47            0
# 47  140.0   97.0    NaN   91.0  ...    NaN        -0.03      48            0
#
# [48 rows x 41 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 41 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   HR                20 non-null     float64
#  1   O2Sat             19 non-null     float64
#  2   Temp              6 non-null      float64
#  3   SBP               19 non-null     float64
#  4   MAP               19 non-null     float64
#  5   DBP               0 non-null      float64
#  6   Resp              20 non-null     float64
#  7   EtCO2             0 non-null      float64
#  8   BaseExcess        0 non-null      float64
#  9   HCO3              4 non-null      float64
#  10  FiO2              0 non-null      float64
#  11  pH                0 non-null      float64
#  12  PaCO2             0 non-null      float64
#  13  SaO2              0 non-null      float64
#  14  AST               0 non-null      float64
#  15  BUN               4 non-null      float64
#  16  Alkalinephos      0 non-null      float64
#  17  Calcium           2 non-null      float64
#  18  Chloride          4 non-null      float64
#  19  Creatinine        2 non-null      float64
#  20  Bilirubin_direct  0 non-null      float64
#  21  Glucose           4 non-null      float64
#  22  Lactate           0 non-null      float64
#  23  Magnesium         4 non-null      float64
#  24  Phosphate         2 non-null      float64
#  25  Potassium         4 non-null      float64
#  26  Bilirubin_total   0 non-null      float64
#  27  TroponinI         0 non-null      float64
#  28  Hct               8 non-null      float64
#  29  Hgb               4 non-null      float64
#  30  PTT               1 non-null      float64
#  31  WBC               4 non-null      float64
#  32  Fibrinogen        0 non-null      float64
#  33  Platelets         2 non-null      float64
#  34  Age               24 non-null     float64
#  35  Gender            24 non-null     int64
#  36  Unit1             0 non-null      float64
#  37  Unit2             0 non-null      float64
#  38  HospAdmTime       24 non-null     float64
#  39  ICULOS            24 non-null     int64
#  40  SepsisLabel       24 non-null     int64
# dtypes: float64(38), int64(3)
# memory usage: 7.8 KB

# %%
df2 = df1.fillna(method='ffill').fillna(method='bfill')
df2
# Out:
#       HR  O2Sat   Temp    SBP  ...  Unit2  HospAdmTime  ICULOS  SepsisLabel
# 0   75.0  100.0  36.89  103.5  ...    NaN        -0.02       1            0
# 1   75.0  100.0  36.89  103.5  ...    NaN        -0.02       2            0
# 2   75.0  100.0  36.89  101.0  ...    NaN        -0.02       3            0
# 3   73.0  100.0  36.89  107.0  ...    NaN        -0.02       4            0
# 4   72.0  100.0  36.89  110.0  ...    NaN        -0.02       5            0
# 5   75.5  100.0  36.89  116.0  ...    NaN        -0.02       6            0
# 6   73.0   99.5  36.78  113.5  ...    NaN        -0.02       7            0
# 7   73.0  100.0  36.78   97.0  ...    NaN        -0.02       8            0
# 8   74.0   99.0  36.78   99.0  ...    NaN        -0.02       9            0
# 9   72.0   99.0  36.78   99.0  ...    NaN        -0.02      10            0
# 10  70.0   98.0  36.67  103.0  ...    NaN        -0.02      11            0
# 11  68.0  100.0  36.67   97.0  ...    NaN        -0.02      12            0
# 12  70.0  100.0  36.67  107.0  ...    NaN        -0.02      13            0
# 13  70.0  100.0  36.67  101.0  ...    NaN        -0.02      14            0
# 14  70.0  100.0  36.72  109.0  ...    NaN        -0.02      15            0
# 15  71.0  100.0  36.72  107.0  ...    NaN        -0.02      16            0
# 16  70.0  100.0  36.72  107.0  ...    NaN        -0.02      17            0
# 17  67.0  100.0  37.17  106.0  ...    NaN        -0.02      18            0
# 18  68.5   96.0  37.17  105.5  ...    NaN        -0.02      19            0
# 19  68.5   96.0  37.17  105.5  ...    NaN        -0.02      20            0
# 20  85.0   99.0  37.17  112.0  ...    NaN        -0.02      21            0
# 21  85.0   99.0  37.17  112.0  ...    NaN        -0.02      22            0
# 22  65.0   97.0  36.89  102.0  ...    NaN        -0.02      23            0
# 23  65.0   97.0  36.89  102.0  ...    NaN        -0.02      24            0
#
# [24 rows x 41 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 41 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   HR                24 non-null     float64
#  1   O2Sat             24 non-null     float64
#  2   Temp              24 non-null     float64
#  3   SBP               24 non-null     float64
#  4   MAP               24 non-null     float64
#  5   DBP               0 non-null      float64
#  6   Resp              24 non-null     float64
#  7   EtCO2             0 non-null      float64
#  8   BaseExcess        0 non-null      float64
#  9   HCO3              24 non-null     float64
#  10  FiO2              0 non-null      float64
#  11  pH                0 non-null      float64
#  12  PaCO2             0 non-null      float64
#  13  SaO2              0 non-null      float64
#  14  AST               0 non-null      float64
#  15  BUN               24 non-null     float64
#  16  Alkalinephos      0 non-null      float64
#  17  Calcium           24 non-null     float64
#  18  Chloride          24 non-null     float64
#  19  Creatinine        24 non-null     float64
#  20  Bilirubin_direct  0 non-null      float64
#  21  Glucose           24 non-null     float64
#  22  Lactate           0 non-null      float64
#  23  Magnesium         24 non-null     float64
#  24  Phosphate         24 non-null     float64
#  25  Potassium         24 non-null     float64
#  26  Bilirubin_total   0 non-null      float64
#  27  TroponinI         0 non-null      float64
#  28  Hct               24 non-null     float64
#  29  Hgb               24 non-null     float64
#  30  PTT               24 non-null     float64
#  31  WBC               24 non-null     float64
#  32  Fibrinogen        0 non-null      float64
#  33  Platelets         24 non-null     float64
#  34  Age               24 non-null     float64
#  35  Gender            24 non-null     int64
#  36  Unit1             0 non-null      float64
#  37  Unit2             0 non-null      float64
#  38  HospAdmTime       24 non-null     float64
#  39  ICULOS            24 non-null     int64
#  40  SepsisLabel       24 non-null     int64
# dtypes: float64(38), int64(3)
# memory usage: 7.8 KB

# %%
stats_df = pd.read_csv('/content/drive/My Drive/sepsis/stats.csv')
stats_df.head()
# Out:
#   column        mean  median
# 0     HR   84.581443    83.5
# 1  O2Sat   97.193955    98.0
# 2   Temp   36.977228    37.0
# 3    SBP  123.750465   121.0
# 4    MAP   82.400100    80.0

# %%
cnt = 1
for f in tqdm(files1):
  df = pd.read_csv(DIR1+f, sep='|')
  f_df = df.fillna(method='ffill').fillna(method='bfill')
  b_df = df.fillna(method='bfill').fillna(method='ffill')
  na_cols = f_df.columns[f_df.isna().any()].tolist()
  for c in na_cols:
    val = float(stats_df[stats_df['column']==c]['mean'])
    f_df[c].fillna(val, inplace=True)
    b_df[c].fillna(val, inplace=True)
  f_df.to_csv(f'/content/drive/My Drive/sepsis/same_fill/front_fill/{cnt}.csv',index=False)
  b_df.to_csv(f'/content/drive/My Drive/sepsis/same_fill/back_fill/{cnt}.csv',index=False)
  cnt += 1
for f in tqdm(files2):
  df = pd.read_csv(DIR2+f, sep='|')
  f_df = df.fillna(method='ffill').fillna(method='bfill')
  b_df = df.fillna(method='bfill').fillna(method='ffill')
  na_cols = f_df.columns[f_df.isna().any()].tolist()
  for c in na_cols:
    val = float(stats_df[stats_df['column']==c]['mean'])
    f_df[c].fillna(val, inplace=True)
    b_df[c].fillna(val, inplace=True)
  f_df.to_csv(f'/content/drive/My Drive/sepsis/same_fill/front_fill/{cnt}.csv',index=False)
  b_df.to_csv(f'/content/drive/My Drive/sepsis/same_fill/back_fill/{cnt}.csv',index=False)
  cnt += 1
# Out:
# HBox(children=(FloatProgress(value=0.0, max=20336.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20000.0), HTML(value='')))

# %%
f_df = pd.concat([pd.read_csv(FDIR+f) for f in tqdm(os.listdir(FDIR))])
f_df.to_csv(FDIR+'dataset.csv',index=False)
b_df = pd.concat([pd.read_csv(BDIR+f) for f in tqdm(os.listdir(BDIR))])
b_df.to_csv(BDIR+'dataset.csv',index=False)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=40336.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=40336.0), HTML(value='')))

# %% [markdown]
# # **BASELINE MODEL**

# %%
f_df = pd.read_csv('/content/drive/My Drive/sepsis/same_fill/front_dataset.csv')

# %%
f_df = f_df.drop(columns=['Gender', 'Unit1', 'Unit2', 'BaseExcess', 'HospAdmTime', 'EtCO2'])

# %%
cols = list(f_df.columns)

# %%
scaler = MinMaxScaler()
scaler.fit(f_df)
base_df = scaler.transform(f_df)
base_df = pd.DataFrame(base_df, columns = cols)
print(base_df.shape)
# Out:
# (1552210, 35)

# %%
X = base_df.drop('SepsisLabel', axis=1)
y = base_df['SepsisLabel']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=50)

# %%
rfc = RandomForestClassifier(n_estimators=100, random_state=50, class_weight='balanced')
rfc.fit(X_train, y_train)
y_pred = rfc.predict(X_test)

# %%
print(roc_auc_score(y_test, y_pred))
# Out:
# 0.8762137745741346

# %%
b_df = pd.read_csv('/content/drive/My Drive/sepsis/same_fill/back_dataset.csv')

# %%
b_df = b_df.drop(columns=['Gender', 'Unit1', 'Unit2', 'BaseExcess', 'HospAdmTime', 'EtCO2'])

# %%
cols = b_df.columns

# %%
scaler = MinMaxScaler()
scaler.fit(b_df)
base_df = scaler.transform(b_df)
base_df = pd.DataFrame(base_df, columns = cols)
print(base_df.shape)
# Out:
# (1552210, 35)

# %%
cols
# Out:
# Index(['HR', 'O2Sat', 'Temp', 'SBP', 'MAP', 'DBP', 'Resp', 'HCO3', 'FiO2',
#        'pH', 'PaCO2', 'SaO2', 'AST', 'BUN', 'Alkalinephos', 'Calcium',
#        'Chloride', 'Creatinine', 'Bilirubin_direct', 'Glucose', 'Lactate',
#        'Magnesium', 'Phosphate', 'Potassium', 'Bilirubin_total', 'TroponinI',
#        'Hct', 'Hgb', 'PTT', 'WBC', 'Fibrinogen', 'Platelets', 'Age', 'ICULOS',
#        'SepsisLabel'],
#       dtype='object')

# %%
X = base_df.drop('SepsisLabel', axis=1)
y = base_df['SepsisLabel']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=50)

# %%
rfc = RandomForestClassifier(n_estimators=100, random_state=50, class_weight='balanced')
rfc.fit(X_train, y_train)
y_pred = rfc.predict(X_test)

# %%
print(roc_auc_score(y_test, y_pred))
# Out:
# 0.9042789253301867

# %%
corrmatrix=f_df.corr()
print(corrmatrix)
# Out:
#                         HR     O2Sat  ...    ICULOS  SepsisLabel
# HR                1.000000 -0.069410  ...  0.046840     0.049836
# O2Sat            -0.069410  1.000000  ... -0.041587    -0.009278
# Temp              0.228196  0.002226  ...  0.089230     0.050597
# SBP              -0.036822  0.040054  ...  0.037895    -0.012318
# MAP               0.062914  0.034521  ...  0.020791    -0.018989
# DBP               0.108629  0.009724  ...  0.006946    -0.015106
# Resp              0.218303 -0.134108  ...  0.092026     0.041619
# EtCO2             0.002383  0.001281  ...  0.068573    -0.006416
# BaseExcess       -0.013219  0.015112  ...  0.098510     0.014796
# HCO3             -0.037451 -0.035728  ...  0.067134    -0.000053
# FiO2              0.001258  0.000017  ... -0.006488    -0.000051
# pH               -0.016687  0.062717  ...  0.154366     0.016553
# PaCO2            -0.001166 -0.079144  ... -0.012744    -0.003425
# SaO2              0.008410  0.046484  ...  0.024440     0.006367
# AST               0.012838 -0.027833  ... -0.041426    -0.003572
# BUN              -0.024866 -0.033190  ...  0.105311     0.042912
# Alkalinephos      0.023709 -0.009754  ... -0.011626     0.003178
# Calcium          -0.077493 -0.028523  ...  0.037950    -0.021568
# Chloride          0.007662  0.085403  ... -0.026057    -0.001865
# Creatinine       -0.021128 -0.003927  ...  0.011921     0.017205
# Bilirubin_direct  0.005132 -0.005965  ...  0.057489     0.008703
# Glucose           0.059029 -0.015673  ... -0.019213     0.012206
# Lactate           0.005130 -0.085825  ... -0.142626    -0.022337
# Magnesium        -0.049853 -0.019143  ...  0.091154     0.014036
# Phosphate        -0.032218 -0.040163  ... -0.019858     0.005857
# Potassium         0.015532 -0.023856  ... -0.037675     0.000135
# Bilirubin_total   0.003697 -0.004637  ...  0.043813     0.014936
# TroponinI         0.010029  0.002608  ... -0.014472     0.003761
# Hct              -0.096710 -0.108651  ... -0.095484    -0.026746
# Hgb              -0.096805 -0.088432  ... -0.107963    -0.027525
# PTT              -0.001398 -0.031639  ... -0.015708     0.004671
# WBC               0.117648 -0.026166  ...  0.013728     0.031813
# Fibrinogen        0.048029 -0.010857  ...  0.085809     0.020488
# Platelets         0.039565 -0.005737  ... -0.009282    -0.002864
# Age              -0.156656 -0.053716  ...  0.010453     0.000191
# Gender           -0.029528 -0.029578  ...  0.014103     0.009280
# Unit1             0.004620 -0.036992  ... -0.009757     0.018849
# Unit2            -0.004620  0.036992  ...  0.009757    -0.018849
# HospAdmTime      -0.056221 -0.008495  ... -0.064456    -0.019051
# ICULOS            0.046840 -0.041587  ...  1.000000     0.133774
# SepsisLabel       0.049836 -0.009278  ...  0.133774     1.000000
#
# [41 rows x 41 columns]

# %%
corrmatrix1=b_df.corr()
print(corrmatrix1)
# Out:
#                         HR     O2Sat  ...    ICULOS  SepsisLabel
# HR                1.000000 -0.069211  ...  0.047672     0.050880
# O2Sat            -0.069211  1.000000  ... -0.041633    -0.008304
# Temp              0.231440  0.009163  ...  0.084924     0.056379
# SBP              -0.037221  0.039384  ...  0.038265    -0.012442
# MAP               0.062421  0.034851  ...  0.020575    -0.019539
# DBP               0.107852  0.009755  ...  0.004470    -0.015386
# Resp              0.218133 -0.135058  ...  0.091610     0.040945
# EtCO2             0.001175 -0.008211  ...  0.057168    -0.006198
# BaseExcess       -0.006509  0.019953  ...  0.100151     0.011264
# HCO3             -0.022188 -0.031030  ...  0.067011    -0.007272
# FiO2              0.001010 -0.002073  ... -0.004468     0.000289
# pH               -0.010265  0.067885  ...  0.143261     0.013219
# PaCO2             0.002958 -0.077310  ...  0.002746    -0.003680
# SaO2              0.005449  0.051744  ...  0.023240     0.005616
# AST               0.013401 -0.031587  ... -0.046137    -0.000810
# BUN              -0.021250 -0.041863  ...  0.119332     0.046644
# Alkalinephos      0.024177 -0.012423  ... -0.001313     0.003717
# Calcium          -0.072125 -0.021744  ...  0.033543    -0.041267
# Chloride         -0.003988  0.091009  ... -0.027573     0.003057
# Creatinine       -0.021478 -0.006351  ...  0.012847     0.019832
# Bilirubin_direct  0.004561 -0.006174  ...  0.056140     0.009139
# Glucose           0.069884 -0.025376  ...  0.000486     0.016091
# Lactate           0.001127 -0.099406  ... -0.131894    -0.020079
# Magnesium        -0.052848 -0.021483  ...  0.072667     0.013134
# Phosphate        -0.036648 -0.043415  ... -0.005332     0.011878
# Potassium         0.004732 -0.024727  ... -0.040122     0.005217
# Bilirubin_total   0.003864 -0.006475  ...  0.049224     0.015333
# TroponinI         0.011148  0.005055  ... -0.016553     0.004154
# Hct              -0.111649 -0.110849  ... -0.085941    -0.021557
# Hgb              -0.113991 -0.091206  ... -0.100525    -0.022274
# PTT               0.003835 -0.039389  ... -0.013314     0.006396
# WBC               0.125709 -0.036435  ...  0.029828     0.039440
# Fibrinogen        0.052511 -0.005219  ...  0.087519     0.018766
# Platelets         0.036243 -0.009722  ...  0.014764     0.001825
# Age              -0.155631 -0.053549  ...  0.010453     0.000191
# Gender           -0.028084 -0.029604  ...  0.014103     0.009280
# Unit1             0.003943 -0.036518  ... -0.009757     0.018849
# Unit2            -0.003943  0.036518  ...  0.009757    -0.018849
# HospAdmTime      -0.055816 -0.007277  ... -0.064456    -0.019051
# ICULOS            0.047672 -0.041633  ...  1.000000     0.133774
# SepsisLabel       0.050880 -0.008304  ...  0.133774     1.000000
#
# [41 rows x 41 columns]

# %%
corrmatrix.to_csv(FDIR+'same_front_corr.csv')

# %%
corrmatrix1.to_csv(BDIR+'same_back_corr.csv')
